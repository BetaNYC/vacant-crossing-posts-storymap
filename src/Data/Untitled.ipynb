# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
data = pd.read_csv('./Crashes_2020.csv')
data.head(3)
# Out:
#    CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/02/2020      10:10  MANHATTAN   10022.0  40.759740  -73.97423
# 1  01/02/2020      13:00  MANHATTAN   10018.0  40.753550  -73.98505
# 2  01/02/2020       9:10  MANHATTAN   10036.0  40.757935  -73.98557
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.75974, -73.97423)  EAST 53 STREET                      MADISON AVENUE
# 1   (40.75355, -73.98505)  AVENUE OF THE AMERICAS              WEST 40 STREET
# 2  (40.757935, -73.98557)  7 AVENUE                            WEST 45 STREET
#
#   OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                 Other Vehicular
# 1             NaN  ...                             NaN
# 2             NaN  ...  Passing or Lane Usage Improper
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# ...

# %%
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format="%H:%M")
data["hour"] = data['CRASH TIME'].dt.hour

# %%
data.to_csv("./crashes_2020.csv")
