# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
data = pd.read_csv('./Motor_Vehicle_Collisions_-_Crashes.csv')
data.head(3)
# Out:
#    CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  04/24/2022      15:35  MANHATTAN   10019.0  40.767242 -73.986206
# 1  04/07/2022      14:14  MANHATTAN   10017.0  40.748158 -73.970330
# 2  03/26/2022       1:02  MANHATTAN   10025.0  40.797836 -73.969460
#
#                   LOCATION   ON STREET NAME CROSS STREET NAME OFF STREET NAME  \
# 0  (40.767242, -73.986206)   WEST 56 STREET          9 AVENUE             NaN
# 1   (40.748158, -73.97033)         1 AVENUE    EAST 41 STREET             NaN
# 2   (40.797836, -73.96946)  WEST 101 STREET          BROADWAY             NaN
#
#    ...   CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0  ...                     Unspecified                            NaN
# 1  ...  Passing or Lane Usage Improper                            NaN
# 2  ...                     Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4521853
# 1                            NaN                            NaN       4522242
# 2                            NaN                            NaN       4513935
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle                                 Bike
# 1                                Sedan  Station Wagon/Sport Utility Vehicle
# 2                                Sedan                                Moped
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
#
# [3 rows x 29 columns]

# %%
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format="%H:%M")
data["hour"] = data['CRASH TIME'].dt.hour

# %%
data.head(3)
# Out:
#    CRASH DATE          CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  04/24/2022 1900-01-01 15:35:00  MANHATTAN   10019.0  40.767242 -73.986206
# 1  04/07/2022 1900-01-01 14:14:00  MANHATTAN   10017.0  40.748158 -73.970330
# 2  03/26/2022 1900-01-01 01:02:00  MANHATTAN   10025.0  40.797836 -73.969460
#
#                   LOCATION   ON STREET NAME CROSS STREET NAME OFF STREET NAME  \
# 0  (40.767242, -73.986206)   WEST 56 STREET          9 AVENUE             NaN
# 1   (40.748158, -73.97033)         1 AVENUE    EAST 41 STREET             NaN
# 2   (40.797836, -73.96946)  WEST 101 STREET          BROADWAY             NaN
#
#    ...  CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0  ...                            NaN                            NaN
# 1  ...                            NaN                            NaN
# 2  ...                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4521853
# 1                            NaN       4522242
# 2                            NaN       4513935
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle                                 Bike
# 1                                Sedan  Station Wagon/Sport Utility Vehicle
# 2                                Sedan                                Moped
#
#    VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5 hour
# 0                  NaN                  NaN                 NaN   15
# 1                  NaN                  NaN                 NaN   14
# 2                  NaN                  NaN                 NaN    1
#
# [3 rows x 30 columns]

# %%
data.to_csv("./crashes.csv")
