# %%
import pandas as pd
import geopandas as gpd
import datetime as dt
import re

# %%
crashes = pd.read_csv('./crashes_from_2020.csv')

# %%
crashes.sample(5)
# Out:
#        Unnamed: 0  CRASH DATE           CRASH TIME    BOROUGH  ZIP CODE  \
# 33028       33028  11/20/2022  1900-01-01 15:00:00  MANHATTAN   10033.0
# 28993       28993  07/25/2022  1900-01-01 12:19:00  MANHATTAN   10011.0
# 9083         9083  10/25/2020  1900-01-01 13:05:00  MANHATTAN   10022.0
# 15738       15738  06/28/2021  1900-01-01 11:44:00  MANHATTAN   10016.0
# 28138       28138  06/29/2022  1900-01-01 17:21:00  MANHATTAN   10027.0
#
#         LATITUDE  LONGITUDE                LOCATION  \
# 33028  40.847996  -73.93470   (40.847996, -73.9347)
# 28993  40.744022  -74.00847  (40.744022, -74.00847)
# 9083   40.759163  -73.97675  (40.759163, -73.97675)
# 15738  40.748363  -73.98041  (40.748363, -73.98041)
# 28138  40.813553  -73.95521  (40.813553, -73.95521)
#
#                          ON STREET NAME      CROSS STREET NAME  ...  \
# 33028                   WEST 179 STREET  SAINT NICHOLAS AVENUE  ...
# 28993                    WEST 16 STREET              11 AVENUE  ...
# ...

# %%
crashes.sample(5).transpose()
# Out:
#                                                           6177   \
# Unnamed: 0                                                 6177
# CRASH DATE                                           07/16/2020
# CRASH TIME                                  1900-01-01 01:50:00
# BOROUGH                                               MANHATTAN
# ZIP CODE                                                10019.0
# LATITUDE                                              40.764053
# LONGITUDE                                             -73.99225
# LOCATION                                 (40.764053, -73.99225)
# ON STREET NAME                 WEST 49 STREET
# CROSS STREET NAME                                     10 AVENUE
# OFF STREET NAME                                             NaN
# NUMBER OF PERSONS INJURED                                     0
# NUMBER OF PERSONS KILLED                                      0
# NUMBER OF PEDESTRIANS INJURED                                 0
# ...

# %%
#only export columns that we need
crashes[['CRASH DATE','hour',
         'LATITUDE','LONGITUDE',
         'NUMBER OF PERSONS INJURED',
         'NUMBER OF PERSONS KILLED',
         'NUMBER OF PEDESTRIANS INJURED',
         'NUMBER OF PEDESTRIANS KILLED',
         'CONTRIBUTING FACTOR VEHICLE 1',
         'CONTRIBUTING FACTOR VEHICLE 2',
         'CONTRIBUTING FACTOR VEHICLE 3']].to_csv('crashes_2020_08_2023.csv', index = False)

# %%
crossing_posts = gpd.read_file('./crossing_locations.geo.json')

# %%
re.findall('([-]?\d+.\d+)','POINT (-73.92184 40.86527)')
# Out:
# ['-73.92184', '40.86527']

# %%
crossing_posts[['LONGITUDE','LATITUDE']] = crossing_posts['geometry'].apply(
    lambda x: pd.Series(re.findall(r'([-]?\d+.\d+)', str(x)))
)

crossing_posts[[
    'POST #',
    'SCHOOL NAME',
    'LAST NAME',
    'STREET NAME 1',
    'STREET NAME 2',
    'AM HOURS',
    'PM HOURS',
    'LONGITUDE',
    'LATITUDE'
]].to_csv('crossing_posts.csv', index = False)
